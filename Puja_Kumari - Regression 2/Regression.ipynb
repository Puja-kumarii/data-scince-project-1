# %% [markdown]
# ## Regression Project

# %% [markdown]
# ### Name : Puja Kumari

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataframe=pd.read_csv('HousePrices.csv')

# %%
dataframe.shape
# Out:
# (1460, 81)

# %%
dataframe.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
dataframe.head(11)
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0    1          60       RL         65.0     8450   Pave   NaN      Reg
# 1    2          20       RL         80.0     9600   Pave   NaN      Reg
# 2    3          60       RL         68.0    11250   Pave   NaN      IR1
# 3    4          70       RL         60.0     9550   Pave   NaN      IR1
# 4    5          60       RL         84.0    14260   Pave   NaN      IR1
# 5    6          50       RL         85.0    14115   Pave   NaN      IR1
# 6    7          20       RL         75.0    10084   Pave   NaN      Reg
# 7    8          60       RL          NaN    10382   Pave   NaN      IR1
# 8    9          50       RM         51.0     6120   Pave   NaN      Reg
# 9   10         190       RL         50.0     7420   Pave   NaN      Reg
# 10  11          20       RL         70.0    11200   Pave   NaN      Reg
#
#    LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# ...

# %%
dataframe.tail(11)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1449  1450         180       RM         21.0     1533   Pave   NaN      Reg
# 1450  1451          90       RL         60.0     9000   Pave   NaN      Reg
# 1451  1452          20       RL         78.0     9262   Pave   NaN      Reg
# 1452  1453         180       RM         35.0     3675   Pave   NaN      Reg
# 1453  1454          20       RL         90.0    17217   Pave   NaN      Reg
# 1454  1455          20       FV         62.0     7500   Pave  Pave      Reg
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
dataframe.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
## Fill Missing Values

dataframe['LotFrontage']=test_df['LotFrontage'].fillna(test_df['LotFrontage'].mean())

# %%
dataframe['MSZoning']=test_df['MSZoning'].fillna(test_df['MSZoning'].mode()[0])

# %%
dataframe.shape
# Out:
# (1460, 81)

# %%
dataframe.drop(dataframe.columns[[0, 1, 2]], axis=1)
# Out:
#       LotFrontage  LotArea Street Alley LotShape LandContour Utilities  \
# 0            65.0     8450   Pave   NaN      Reg         Lvl    AllPub
# 1            80.0     9600   Pave   NaN      Reg         Lvl    AllPub
# 2            68.0    11250   Pave   NaN      IR1         Lvl    AllPub
# 3            60.0     9550   Pave   NaN      IR1         Lvl    AllPub
# 4            84.0    14260   Pave   NaN      IR1         Lvl    AllPub
# ...           ...      ...    ...   ...      ...         ...       ...
# 1455         62.0     7917   Pave   NaN      Reg         Lvl    AllPub
# 1456         85.0    13175   Pave   NaN      Reg         Lvl    AllPub
# 1457         66.0     9042   Pave   NaN      Reg         Lvl    AllPub
# 1458         68.0     9717   Pave   NaN      Reg         Lvl    AllPub
# 1459         75.0     9937   Pave   NaN      Reg         Lvl    AllPub
#
#      LotConfig LandSlope Neighborhood  ... PoolArea PoolQC  Fence MiscFeature  \
# ...

# %%
dataframe.drop(['LandContour'],axis =1)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
dataframe.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
dataframe.shape
# Out:
# (1460, 81)

# %%
dataframe['FireplaceQu']=test_df['FireplaceQu'].fillna(test_df['FireplaceQu'].mode()[0])
dataframe['GarageType']=test_df['GarageType'].fillna(test_df['GarageType'].mode()[0])

# %%
dataframe['BsmtCond']=test_df['BsmtCond'].fillna(test_df['BsmtCond'].mode()[0])
dataframe['BsmtQual']=test_df['BsmtQual'].fillna(test_df['BsmtQual'].mode()[0])

# %%
dataframe.drop(['LotArea'],axis=1)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage Street Alley LotShape  \
# 0        1          60       RL         65.0   Pave   NaN      Reg
# 1        2          20       RL         80.0   Pave   NaN      Reg
# 2        3          60       RL         68.0   Pave   NaN      IR1
# 3        4          70       RL         60.0   Pave   NaN      IR1
# 4        5          60       RL         84.0   Pave   NaN      IR1
# ...    ...         ...      ...          ...    ...   ...      ...
# 1455  1456          60       RL         62.0   Pave   NaN      Reg
# 1456  1457          20       RL         85.0   Pave   NaN      Reg
# 1457  1458          70       RL         66.0   Pave   NaN      Reg
# 1458  1459          20       RL         68.0   Pave   NaN      Reg
# 1459  1460          20       RL         75.0   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# 0            Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# ...

# %%
dataframe.shape
# Out:
# (1460, 81)

# %%
dataframe['GarageFinish']=test_df['GarageFinish'].fillna(test_df['GarageFinish'].mode()[0])
dataframe['GarageQual']=test_df['GarageQual'].fillna(test_df['GarageQual'].mode()[0])
dataframe['GarageCond']=test_df['GarageCond'].fillna(test_df['GarageCond'].mode()[0])

# %%
dataframe.drop(['Alley','PoolArea','PoolQC'],axis=1)
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0             60       RL         65.0     8450   Pave      Reg         Lvl
# 1             20       RL         80.0     9600   Pave      Reg         Lvl
# 2             60       RL         68.0    11250   Pave      IR1         Lvl
# 3             70       RL         60.0     9550   Pave      IR1         Lvl
# 4             60       RL         84.0    14260   Pave      IR1         Lvl
# ...          ...      ...          ...      ...    ...      ...         ...
# 1455          60       RL         62.0     7917   Pave      Reg         Lvl
# 1456          20       RL         85.0    13175   Pave      Reg         Lvl
# 1457          70       RL         66.0     9042   Pave      Reg         Lvl
# 1458          20       RL         68.0     9717   Pave      Reg         Lvl
# 1459          20       RL         75.0     9937   Pave      Reg         Lvl
#
# ...

# %%
dataframe.shape
# Out:
# (1460, 81)

# %%
dataframe.drop(['Id'],axis=1,inplace=True)

# %%
dataframe['MasVnrType']=test_df['MasVnrType'].fillna(test_df['MasVnrType'].mode()[0])
dataframe['MasVnrArea']=test_df['MasVnrArea'].fillna(test_df['MasVnrArea'].mode()[0])

# %%
sns.heatmap(dataframe.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
dataframe['BsmtExposure']=dataframe['BsmtExposure'].fillna(dataframe['BsmtExposure'].mode()[0])

# %%
sns.heatmap(dataframe.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
dataframe['BsmtFinType2']=dataframe['BsmtFinType2'].fillna(dataframe['BsmtFinType2'].mode()[0])

# %%
dataframe.loc[:, dataframe.isnull().any()].head()
# Out:
#   Alley BsmtFinType1 Electrical  GarageYrBlt PoolQC Fence MiscFeature
# 0   NaN          GLQ      SBrkr       2003.0    NaN   NaN         NaN
# 1   NaN          ALQ      SBrkr       1976.0    NaN   NaN         NaN
# 2   NaN          GLQ      SBrkr       2001.0    NaN   NaN         NaN
# 3   NaN          ALQ      SBrkr       1998.0    NaN   NaN         NaN
# 4   NaN          GLQ      SBrkr       2000.0    NaN   NaN         NaN

# %%
dataframe['KitchenQual']=dataframe['KitchenQual'].fillna(dataframe['KitchenQual'].mode()[0])
dataframe['Functional']=dataframe['Functional'].fillna(dataframe['Functional'].mode()[0])
dataframe['GarageCars']=dataframe['GarageCars'].fillna(dataframe['GarageCars'].mean())
dataframe['GarageArea']=dataframe['GarageArea'].fillna(dataframe['GarageArea'].mean())
dataframe['SaleType']=dataframe['SaleType'].fillna(dataframe['SaleType'].mode()[0])
dataframe['Exterior1st']=dataframe['Exterior1st'].fillna(dataframe['Exterior1st'].mode()[0])
dataframe['Exterior2nd']=dataframe['Exterior2nd'].fillna(dataframe['Exterior2nd'].mode()[0])
dataframe['BsmtFinType1']=dataframe['BsmtFinType1'].fillna(dataframe['BsmtFinType1'].mode()[0])
dataframe['BsmtFinSF1']=dataframe['BsmtFinSF1'].fillna(dataframe['BsmtFinSF1'].mean())
dataframe['BsmtFinSF2']=dataframe['BsmtFinSF2'].fillna(dataframe['BsmtFinSF2'].mean())
dataframe['BsmtUnfSF']=dataframe['BsmtUnfSF'].fillna(dataframe['BsmtUnfSF'].mean())
dataframe['TotalBsmtSF']=dataframe['TotalBsmtSF'].fillna(dataframe['TotalBsmtSF'].mean())
dataframe['BsmtFullBath']=dataframe['BsmtFullBath'].fillna(dataframe['BsmtFullBath'].mode()[0])
dataframe['BsmtHalfBath']=dataframe['BsmtHalfBath'].fillna(dataframe['BsmtHalfBath'].mode()[0])

# %%
dataframe.shape
# Out:
# (1460, 80)
